# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
from pprint import pprint
import matplotlib.pyplot as plt
import json
import tiktoken
from tqdm import tqdm

# %% [markdown]
# ### Open the JSON file with the collected data

# %%
file_path = 'simple-scraped-kernels.json'

# Open and load the JSON file
with open(file_path, 'r') as file:
    data = json.load(file)

# %% [markdown]
# ### Let's create a dataframe to store the stats of each kernel

# %%
df = pd.DataFrame()
enc = tiktoken.encoding_for_model("gpt-4o-mini")

# %%
for target in tqdm(data, desc='Counting tokens'):
    basename = target['basename']
    kernelNames = target['kernelNames']
    for kern in kernelNames:
        statsDict = {'target':[basename], 'kernelName': [kern]}
        kernCtx = target['kernels'][kern]
        #print(kernCtx)
        encoded = enc.encode(kernCtx)
        statsDict['numTokens'] = [len(encoded)]

        kernDF = pd.DataFrame.from_dict(statsDict).astype({'target': str, 'kernelName': str, 'numTokens': int})
        df = pd.concat([df, kernDF], ignore_index=True)
# Out:
# Counting tokens: 100%|██████████| 749/749 [00:21<00:00, 34.36it/s]

# %%
# let's check our dataframe
print(df.shape)
print(df.head(10))

cudaDF = df[df['target'].str.contains('-cuda')]
cudaDF = cudaDF.sort_values(by=['numTokens'], ascending=True, ignore_index=True)

ompDF = df[df['target'].str.contains('-omp')]
ompDF = ompDF.sort_values(by=['numTokens'], ascending=True, ignore_index=True)

# this is cost in USD
costPer1e6Tokens = 0.15

# add some stats to the dataset
cudaDF['totalSumTokens'] = cudaDF['numTokens'].cumsum()
cudaDF['totalInfCost'] = costPer1e6Tokens*(cudaDF['totalSumTokens']/1e6)

ompDF['totalSumTokens'] = ompDF['numTokens'].cumsum()
ompDF['totalInfCost'] = costPer1e6Tokens*(ompDF['totalSumTokens']/1e6)

print(cudaDF.shape)
print(cudaDF.head(10))
print()
print()
print(ompDF.shape)
print(ompDF.head(10))
# Out:
# (2171, 3)
#           target                                         kernelName  numTokens
# 0  accuracy-cuda                                    accuracy_kernel       1154
# 1   accuracy-omp            __omp_offloading_10309_2f04138_main_l57        764
# 2       ace-cuda                                          allenCahn       7879
# 3       ace-cuda                                    thermalEquation       7879
# 4       ace-cuda                                           swapGrid       7879
# 5       ace-cuda                                     calculateForce       7879
# 6       ace-cuda                                boundaryConditionsU       7879
# 7       ace-cuda                              boundaryConditionsPhi       7879
# 8        ace-omp  __omp_offloading_10309_2f0414b__Z14calculateFo...       4458
# 9        ace-omp  __omp_offloading_10309_2f0414b__Z9allenCahnPA4...       4458
# (1151, 5)
#                  target              kernelName  numTokens  totalSumTokens  \
# 0          reverse-cuda                 reverse        577             577
# 1  atomicAggregate-cuda                       k        718            1295
# 2         dispatch-cuda             EmptyKernel        807            2102
# 3           assert-cuda             perfKernel2        836            2938
# 4           assert-cuda              perfKernel        836            3774
# 5    matrix-rotate-cuda  rotate_matrix_parallel        885            4659
# 6         mixbench-cuda          benchmark_func        901            5560
# 7      michalewicz-cuda                    eval        933            6493
# 8     kernelLaunch-cuda     KernelWithLargeArgs        996            7489
# 9     kernelLaunch-cuda     KernelWithSmallArgs        996            8485
#
#    totalInfCost
# 0      0.000087
# 1      0.000194
# 2      0.000315
# 3      0.000441
# 4      0.000566
# 5      0.000699
# 6      0.000834
# 7      0.000974
# 8      0.001123
# 9      0.001273
#
#
# (1020, 5)
#             target                                         kernelName  \
# 0    haversine-omp  __omp_offloading_10309_2f284a8__Z15distance_de...
# 1     lebesgue-omp  __omp_offloading_10309_2fc44eb__Z17lebesgue_fu...
# 2    wordcount-omp  __omp_offloading_10309_2fc6292__Z10word_countR...
# 3      reverse-omp            __omp_offloading_10309_2fc5811_main_l52
# 4        norm2-omp            __omp_offloading_10309_2fc53bf_main_l51
# 5  michalewicz-omp            __omp_offloading_10309_2fc4c98_main_l73
# 6          pso-omp  __omp_offloading_10309_2fc566a__Z20kernelUpdat...
# 7          pso-omp  __omp_offloading_10309_2fc566a__Z17kernelUpdat...
# 8     accuracy-omp            __omp_offloading_10309_2f04138_main_l57
# 9        gabor-omp  __omp_offloading_10309_2f086a7__Z25generateGab...
#
#    numTokens  totalSumTokens  totalInfCost
# 0        304             304      0.000046
# 1        355             659      0.000099
# 2        532            1191      0.000179
# 3        563            1754      0.000263
# 4        692            2446      0.000367
# 5        725            3171      0.000476
# 6        751            3922      0.000588
# 7        751            4673      0.000701
# 8        764            5437      0.000816
# 9        781            6218      0.000933

# %%
fig, ax = plt.subplots(1, figsize=(12,6))


sns.histplot(cudaDF, x='numTokens', bins=300, ax=ax, log_scale=True, color='blue')
sns.histplot(ompDF, x='numTokens', bins=300, ax=ax, log_scale=True, color='orange')
ax2 = ax.twinx()
sns.ecdfplot(cudaDF, x='numTokens', ax=ax2, log_scale=True, color='blue')
sns.ecdfplot(ompDF, x='numTokens', ax=ax2, log_scale=True, color='orange')

ax.set_xlabel('Number of Tokens')
ax.set_ylabel('Number of Kernels')
ax2.set_ylabel('Proportion of Total Kernels')

ax.legend(['CUDA Codes', 'OMP Codes'])

ax.set_title('gpt-4o-mini Token Distribution Histogram (simple sourcefile scraping of CUDA+OMP codes)')

plt.show()

# %% [markdown]
# ### Expected Cost Analysis

# %%
# sort the dataframe by token count

# %%
# given a sorted dataframe
def getNumTokensCDF(df, percent):
    numRows = df.shape[0]
    # map the percent to the numRows range
    idx = int(percent * (numRows-1))
    numTokens = df.iloc[idx]['numTokens']
    return numTokens

def getNumSamplesLTETokenCount(df, tokCount):
    subset = df[df['numTokens'] <= tokCount]
    return subset.shape[0]

# %%
percents = [0.1, 0.25, 0.5, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.96, 0.97, 0.98, 0.99, 1.0]

for perc in percents:
    print(f'  CUDA {int(100*perc)}% of samples have token count <= {getNumTokensCDF(cudaDF, perc)} tokens ({getNumSamplesLTETokenCount(cudaDF, getNumTokensCDF(cudaDF, perc))} samples)')
    print(f'OPENMP {int(100*perc)}% of samples have token count <= {getNumTokensCDF(ompDF, perc)} tokens ({getNumSamplesLTETokenCount(ompDF, getNumTokensCDF(ompDF, perc))} samples)')
    print()

print(f'  CUDA Num samples with less than 25k tokens: {getNumSamplesLTETokenCount(cudaDF, 25000)}')
print(f'OPENMP Num samples with less than 25k tokens: {getNumSamplesLTETokenCount(ompDF, 25000)}')
# Out:
#   CUDA 10% of samples have token count <= 2012 tokens (117 samples)
# OPENMP 10% of samples have token count <= 1195 tokens (102 samples)
#
#   CUDA 25% of samples have token count <= 3351 tokens (288 samples)
# OPENMP 25% of samples have token count <= 1971 tokens (255 samples)
#
#   CUDA 50% of samples have token count <= 7419 tokens (587 samples)
# OPENMP 50% of samples have token count <= 3797 tokens (511 samples)
#
#   CUDA 60% of samples have token count <= 9738 tokens (692 samples)
# OPENMP 60% of samples have token count <= 6570 tokens (612 samples)
#
#   CUDA 65% of samples have token count <= 11288 tokens (754 samples)
# OPENMP 65% of samples have token count <= 7452 tokens (673 samples)
#
#   CUDA 70% of samples have token count <= 14448 tokens (809 samples)
# OPENMP 70% of samples have token count <= 9007 tokens (716 samples)
#
#   CUDA 75% of samples have token count <= 18670 tokens (865 samples)
# OPENMP 75% of samples have token count <= 10423 tokens (771 samples)
#
#   CUDA 80% of samples have token count <= 33770 tokens (921 samples)
# OPENMP 80% of samples have token count <= 13348 tokens (824 samples)
#
#   CUDA 85% of samples have token count <= 42036 tokens (989 samples)
# OPENMP 85% of samples have token count <= 22847 tokens (872 samples)
#
#   CUDA 90% of samples have token count <= 50892 tokens (1036 samples)
# OPENMP 90% of samples have token count <= 33096 tokens (928 samples)
#
#   CUDA 95% of samples have token count <= 100369 tokens (1094 samples)
# OPENMP 95% of samples have token count <= 59642 tokens (992 samples)
#
#   CUDA 96% of samples have token count <= 119412 tokens (1109 samples)
# OPENMP 96% of samples have token count <= 59642 tokens (992 samples)
#
#   CUDA 97% of samples have token count <= 178204 tokens (1129 samples)
# OPENMP 97% of samples have token count <= 59642 tokens (992 samples)
#
#   CUDA 98% of samples have token count <= 178204 tokens (1129 samples)
# OPENMP 98% of samples have token count <= 209742 tokens (1009 samples)
#
#   CUDA 99% of samples have token count <= 219600 tokens (1141 samples)
# OPENMP 99% of samples have token count <= 209742 tokens (1009 samples)
#
#   CUDA 100% of samples have token count <= 779889 tokens (1151 samples)
# OPENMP 100% of samples have token count <= 3949624 tokens (1020 samples)
#
#   CUDA Num samples with less than 25k tokens: 890
# OPENMP Num samples with less than 25k tokens: 897

# %%
def calcMinCostOfInferenceForPercentOfDF(df, percent):
    numRows = df.shape[0]
    # map the percent to the numRows range
    idx = int(percent * (numRows-1))

    subset = df.iloc[0:idx+1]

    totalNumTokens = subset['numTokens'].sum()

    cost = costPer1e6Tokens * (totalNumTokens/1e6)

    return cost

# %%
for perc in percents:
    print(f'  CUDA Min expected cost to inference smallest {int(100*perc)}% of dataset: ${round(calcMinCostOfInferenceForPercentOfDF(cudaDF, perc),4)}')
    print(f'OPENMP Min expected cost to inference smallest {int(100*perc)}% of dataset: ${round(calcMinCostOfInferenceForPercentOfDF(ompDF, perc),4)}')
    print()
# Out:
#   CUDA Min expected cost to inference smallest 10% of dataset: $0.0267
# OPENMP Min expected cost to inference smallest 10% of dataset: $0.0153
#
#   CUDA Min expected cost to inference smallest 25% of dataset: $0.0955
# OPENMP Min expected cost to inference smallest 25% of dataset: $0.054
#
#   CUDA Min expected cost to inference smallest 50% of dataset: $0.3114
# OPENMP Min expected cost to inference smallest 50% of dataset: $0.158
#
#   CUDA Min expected cost to inference smallest 60% of dataset: $0.4568
# OPENMP Min expected cost to inference smallest 60% of dataset: $0.2296
#
#   CUDA Min expected cost to inference smallest 65% of dataset: $0.5483
# OPENMP Min expected cost to inference smallest 65% of dataset: $0.2843
#
#   CUDA Min expected cost to inference smallest 70% of dataset: $0.6586
# OPENMP Min expected cost to inference smallest 70% of dataset: $0.3463
#
#   CUDA Min expected cost to inference smallest 75% of dataset: $0.7956
# OPENMP Min expected cost to inference smallest 75% of dataset: $0.4192
#
#   CUDA Min expected cost to inference smallest 80% of dataset: $1.0237
# OPENMP Min expected cost to inference smallest 80% of dataset: $0.5095
#
#   CUDA Min expected cost to inference smallest 85% of dataset: $1.3486
# OPENMP Min expected cost to inference smallest 85% of dataset: $0.6381
#
#   CUDA Min expected cost to inference smallest 90% of dataset: $1.7663
# OPENMP Min expected cost to inference smallest 90% of dataset: $0.8387
#
#   CUDA Min expected cost to inference smallest 95% of dataset: $2.3588
# OPENMP Min expected cost to inference smallest 95% of dataset: $1.1777
#
#   CUDA Min expected cost to inference smallest 96% of dataset: $2.5709
# OPENMP Min expected cost to inference smallest 96% of dataset: $1.2671
#
#   CUDA Min expected cost to inference smallest 97% of dataset: $2.805
# OPENMP Min expected cost to inference smallest 97% of dataset: $1.3566
#
#   CUDA Min expected cost to inference smallest 98% of dataset: $3.1258
# OPENMP Min expected cost to inference smallest 98% of dataset: $1.4709
#
#   CUDA Min expected cost to inference smallest 99% of dataset: $3.4815
# OPENMP Min expected cost to inference smallest 99% of dataset: $1.7856
#
#   CUDA Min expected cost to inference smallest 100% of dataset: $4.523
# OPENMP Min expected cost to inference smallest 100% of dataset: $6.1874

# %%
fig, ax = plt.subplots(1, figsize=(12,6))

sns.histplot(cudaDF, x='numTokens', bins=300, ax=ax, log_scale=True, color='blue')
sns.histplot(ompDF, x='numTokens', bins=300, ax=ax, log_scale=True, color='orange')
ax2 = ax.twinx()
sns.lineplot(cudaDF.groupby(['numTokens'])['totalInfCost'].max().reset_index().sort_values(by=['numTokens'], ascending=True, ignore_index=True), x='numTokens', y='totalInfCost', ax=ax2)
sns.lineplot(ompDF.groupby(['numTokens'])['totalInfCost'].max().reset_index().sort_values(by=['numTokens'], ascending=True, ignore_index=True), x='numTokens', y='totalInfCost', ax=ax2)

ax.set_xlabel('Number of Tokens')
ax.set_ylabel('Number of Samples')
ax2.set_ylabel('Minimum Cost of Inference (in USD)')

ax.legend(['CUDA Codes', 'OMP Codes'])

ax.set_title('gpt-4o-mini Token Distribution Histogram (simple sourcefile scraping of CUDA+OMP codes)')

plt.show()

# %% [markdown]
# ### Pruning the Dataset

# %%
def savePercentOfDF(df, percent, outfile):
    numRows = df.shape[0]
    # map the percent to the numRows range
    idx = int(percent * (numRows-1))

    subset = df.iloc[0:idx+1]

    targetNames = list(subset['target'].unique())

    subset = df[df['target'].isin(targetNames)]

    tosave = []

    for target in tqdm(data, desc='Gathering targets to export'):
        basename = target['basename']
        if basename in targetNames:
            tosave.append(target)

    with open(outfile, 'w') as fp:
        json.dump(tosave, fp, indent=4)

    print(f'Expected min inference cost: ${round(subset.iloc[subset.shape[0]-1]["totalInfCost"], 3)} for {outfile}')
    print(f'Num kernels: {subset.shape[0]} for {outfile}')
    print()


def saveMaxTokenCountOfDF(df, maxTokens, outfile):
    subset = df[df['numTokens'] <= maxTokens]

    targetNames = list(subset['target'].unique())

    subset = df[df['target'].isin(targetNames)]

    tosave = []

    for target in data:
        basename = target['basename']
        if basename in targetNames:
            tosave.append(target)

    with open(outfile, 'w') as fp:
        json.dump(tosave, fp, indent=4)

    print(f'Expected min inference cost: ${round(subset.iloc[subset.shape[0]-1]["totalInfCost"], 3)} for {outfile}')
    print(f'Num kernels: {subset.shape[0]} for {outfile}')
    print()

# %%
#savePercentOfDF(cudaDF, 0.65, 'simple-scraped-kernels-CUDA-pruned.json')
#savePercentOfDF(ompDF, 0.65, 'simple-scraped-kernels-OMP-pruned.json')

saveMaxTokenCountOfDF(cudaDF, 7452, '../dataset-gen/simple-scraped-kernels-CUDA-pruned.json')
saveMaxTokenCountOfDF(ompDF, 7452, '../dataset-gen/simple-scraped-kernels-OMP-pruned.json')
# Out:
# Expected min inference cost: $0.324 for ../dataset-gen/simple-scraped-kernels-CUDA-pruned.json
# Num kernels: 587 for ../dataset-gen/simple-scraped-kernels-CUDA-pruned.json
#
# Expected min inference cost: $0.296 for ../dataset-gen/simple-scraped-kernels-OMP-pruned.json
# Num kernels: 673 for ../dataset-gen/simple-scraped-kernels-OMP-pruned.json

# %%
saveMaxTokenCountOfDF(cudaDF, 8e3, '../dataset-gen/simple-scraped-kernels-CUDA-pruned.json')
saveMaxTokenCountOfDF(ompDF, 8e3, '../dataset-gen/simple-scraped-kernels-OMP-pruned.json')
# Out:
# Expected min inference cost: $0.347 for ../dataset-gen/simple-scraped-kernels-CUDA-pruned.json
# Num kernels: 607 for ../dataset-gen/simple-scraped-kernels-CUDA-pruned.json
#
# Expected min inference cost: $0.308 for ../dataset-gen/simple-scraped-kernels-OMP-pruned.json
# Num kernels: 684 for ../dataset-gen/simple-scraped-kernels-OMP-pruned.json
